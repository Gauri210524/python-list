# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/python-list/blob/main/25_01_2025_list_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=["aman",123,4.5,True]
print(a)
# Out:
# ['aman', 123, 4.5, True]

# %%
fruits=['banana','mango','apple']
#friends=['aman','arun','anil']
#for fruit in fruits:
  #if fruit=='banana':
     #print('found')
  #else:
    #print('not fount')
len=len(fruits)
for i in range(len):
      print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3808112166.py in <cell line: 0>()
#       6   #else:
#       7     #print('not fount')
# ----> 8 len=len(fruits)
#       9 for i in range(len):
#      10       print(i)
#
# TypeError: 'int' object is not callable

# %%
fruits=['banana','mango','apple']
for 'banana' in fruits:
  print('banana')
# Out:
#   File "/tmp/ipython-input-1639135162.py", line 2
#     for 'banana' in fruits:
#         ^
# SyntaxError: cannot assign to literal

# %%
city=['delhi','mumbai','noida','gurgaon','chennai']
user_input=input()
if user_input in city:
    print('servicible')
else:
    print('not servicible')
# Out:
# ghhj
# not servicible
